# %%
# Need to do this before importing RV when running in a Docker container from VS Code.
# This has to do with the fact that VS Code is not setting env vars in the notebook correctly.
import os
os.environ['GDAL_DATA'] = '/opt/conda/lib/python3.7/site-packages/rasterio/gdal_data/'

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from os.path import join

from rastervision.pytorch_learner.dataset import SemanticSegmentationSlidingWindowGeoDataset
from rastervision.pytorch_learner.visualizer import SemanticSegmentationVisualizer
from rastervision.core.data import ClassConfig

TRAIN_IDS = [
    '2_10', '2_11', '3_10', '3_11', '4_10', '4_11', '4_12', '5_10', '5_11',
    '5_12', '6_10', '6_11', '6_7', '6_9', '7_10', '7_11', '7_12', '7_7', '7_8',
    '7_9'
]
VAL_IDS = ['2_12', '3_12', '6_12']

CLASS_NAMES = [
    'Car', 'Building', 'Low Vegetation', 'Tree', 'Impervious', 'Clutter'
]
CLASS_COLORS = [
    '#ffff00', '#0000ff', '#00ffff', '#00ff00', '#ffffff', '#ff0000'
]

# %%
class_config = ClassConfig(names=CLASS_NAMES, colors=CLASS_COLORS)
channel_order = [0, 1, 2, 3]
channel_display_groups = {'RGB': (0, 1, 2), 'IR': (3, )}

scene_id = '2_10'
scene_id = scene_id.replace('-', '_')
raw_uri = 's3://raster-vision-raw-data/isprs-potsdam'
image_uri = join(raw_uri, f'4_Ortho_RGBIR/top_potsdam_{scene_id}_RGBIR.tif')
label_uri = join(raw_uri, f'5_Labels_for_participants/top_potsdam_{scene_id}_label.tif')

ds = SemanticSegmentationSlidingWindowGeoDataset.from_uris(
    class_config=class_config,
    image_uri=image_uri,
    label_raster_uri=label_uri,
    size=300,
    stride=150,
    image_raster_source_kw={'channel_order': channel_order})
# Out:
# 2022-09-02 19:08:31:rastervision.pipeline.file_system.utils: INFO - Using cached file /opt/data/tmp/cache/s3/raster-vision-raw-data/isprs-potsdam/4_Ortho_RGBIR/top_potsdam_2_10_RGBIR.tif.
# 2022-09-02 19:08:32:rastervision.pipeline.file_system.utils: INFO - Using cached file /opt/data/tmp/cache/s3/raster-vision-raw-data/isprs-potsdam/5_Labels_for_participants/top_potsdam_2_10_label.tif.
# 2022-09-02 19:08:32:rastervision.pipeline.file_system.utils: INFO - Using cached file /opt/data/tmp/cache/s3/raster-vision-raw-data/isprs-potsdam/4_Ortho_RGBIR/top_potsdam_2_10_RGBIR.tif.
# 2022-09-02 19:08:33:rastervision.pipeline.file_system.utils: INFO - Using cached file /opt/data/tmp/cache/s3/raster-vision-raw-data/isprs-potsdam/5_Labels_for_participants/top_potsdam_2_10_label.tif.

# %%
vis = SemanticSegmentationVisualizer()
x, y = vis.get_batch(ds, 4)
vis.plot_batch(x, y, show=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_92219/1892039670.py in <module>
#       1 vis = SemanticSegmentationVisualizer()
#       2 x, y = vis.get_batch(ds, 4)
# ----> 3 vis.plot_batch(x, y, show=True)
#
# /opt/src/rastervision_pytorch_learner/rastervision/pytorch_learner/visualizer/visualizer.py in plot_batch(self, x, y, output_path, z, batch_limit, show)
#     111         for i, row_axs in enumerate(axs):
#     112             if z is None:
# --> 113                 self.plot_xyz(row_axs, x[i], y[i], **plot_xyz_args)
#     114             else:
#     115                 self.plot_xyz(row_axs, x[i], y[i], z=z[i], **plot_xyz_args)
#
# /opt/src/rastervision_pytorch_learner/rastervision/pytorch_learner/visualizer/semantic_segmentation_visualizer.py in plot_xyz(self, axs, x, y, z)
#      30         colors = [
#      31             color_to_triple(c) if isinstance(c, str) else c
# ---> 32             for c in class_colors
#      33         ]
#      34         colors = np.array(colors) / 255.
#
# TypeError: 'NoneType' object is not iterable
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x40f7d695f0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/matplotlib/pyplot.py in post_execute()
#     135     def post_execute():
#     136         if matplotlib.is_interactive():
# --> 137             draw_all()
#     138
#     139     try:  # IPython >= 2
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     139         for manager in cls.get_all_fig_managers():
#     140             if force or manager.canvas.figure.stale:
# --> 141                 manager.canvas.draw_idle()
#     142
#     143
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2058         if not self._is_idle_drawing:
#    2059             with self._idle_draw_cntx():
# -> 2060                 self.draw(*args, **kwargs)
#    2061
#    2062     @property
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     434              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     435               else nullcontext()):
# --> 436             self.figure.draw(self.renderer)
#     437             # A GUI class may be need to update a window using this draw, so
#     438             # don't forget to call the superclass.
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      72     @wraps(draw)
#      73     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74         result = draw(artist, renderer, *args, **kwargs)
#      75         if renderer._rasterizing:
#      76             renderer.stop_rasterizing()
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    2834             renderer.open_group('figure', gid=self.get_gid())
#    2835             if self.get_constrained_layout() and self.axes:
# -> 2836                 self.execute_constrained_layout(renderer)
#    2837             if self.get_tight_layout() and self.axes:
#    2838                 try:
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/figure.py in execute_constrained_layout(self, renderer)
#    3197             renderer = get_renderer(fig)
#    3198         return do_constrained_layout(fig, renderer, h_pad, w_pad,
# -> 3199                                      hspace, wspace)
#    3200
#    3201     def tight_layout(self, *, pad=1.08, h_pad=None, w_pad=None, rect=None):
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/_constrained_layout.py in do_constrained_layout(fig, renderer, h_pad, w_pad, hspace, wspace)
#     109         # figure.  Add margins for colorbars...
#     110         make_layout_margins(layoutgrids, fig, renderer, h_pad=h_pad,
# --> 111                             w_pad=w_pad, hspace=hspace, wspace=wspace)
#     112         make_margin_suptitles(layoutgrids, fig, renderer, h_pad=h_pad,
#     113                               w_pad=w_pad)
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/_constrained_layout.py in make_layout_margins(layoutgrids, fig, renderer, w_pad, h_pad, hspace, wspace)
#     313         margin = get_margin_from_padding(ax, w_pad=w_pad, h_pad=h_pad,
#     314                                          hspace=hspace, wspace=wspace)
# --> 315         pos, bbox = get_pos_and_bbox(ax, renderer)
#     316         # the margin is the distance between the bounding box of the axes
#     317         # and its position (plus the padding from above)
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/_constrained_layout.py in get_pos_and_bbox(ax, renderer)
#     544     pos = pos.transformed(fig.transSubfigure - fig.transFigure)
#     545     try:
# --> 546         tightbbox = ax.get_tightbbox(renderer=renderer, for_layout_only=True)
#     547     except TypeError:
#     548         tightbbox = ax.get_tightbbox(renderer=renderer)
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4673                     # this artist
#    4674                     continue
# -> 4675             bbox = a.get_tightbbox(renderer)
#    4676             if (bbox is not None
#    4677                     and 0 < bbox.width < np.inf
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/artist.py in get_tightbbox(self, renderer)
#     354             The enclosing bounding box (in figure pixel coordinates).
#     355         """
# --> 356         bbox = self.get_window_extent(renderer)
#     357         if self.get_clip_on():
#     358             clip_box = self.get_clip_box()
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/patches.py in get_window_extent(self, renderer)
#     627
#     628     def get_window_extent(self, renderer=None):
# --> 629         return self.get_path().get_extents(self.get_transform())
#     630
#     631     def _convert_xy_units(self, xy):
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/path.py in get_extents(self, transform, **kwargs)
#     612         from .transforms import Bbox
#     613         if transform is not None:
# --> 614             self = transform.transform_path(self)
#     615         if self.codes is None:
#     616             xys = self.vertices
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/transforms.py in transform_path(self, path)
#    1606         that began as line segments.
#    1607         """
# -> 1608         return self.transform_path_affine(self.transform_path_non_affine(path))
#    1609
#    1610     def transform_path_affine(self, path):
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/transforms.py in transform_path_affine(self, path)
#    1616         ``transform_path_affine(transform_path_non_affine(values))``.
#    1617         """
# -> 1618         return self.get_affine().transform_path_affine(path)
#    1619
#    1620     def transform_path_non_affine(self, path):
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/transforms.py in get_affine(self)
#    2445         else:
#    2446             return Affine2D(np.dot(self._b.get_affine().get_matrix(),
# -> 2447                                    self._a.get_affine().get_matrix()))
#    2448
#    2449     def inverted(self):
#
# KeyboardInterrupt:

# %%
vis = SemanticSegmentationVisualizer(
    CLASS_NAMES, CLASS_COLORS, channel_display_groups=channel_display_groups)
vis.plot_batch(x, y, show=True)
